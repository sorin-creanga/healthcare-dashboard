# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\sorin.creanga\Desktop\Medcare\base-data\ER Wait Time Dataset.csv", index_col=0)
df.info
# Out:
# <bound method DataFrame.info of                      Patient ID Hospital ID                 Hospital Name  \
# Visit ID
# HOSP-1-20240210-0001  PAT-00001      HOSP-1  Springfield General Hospital
# HOSP-3-20241128-0001  PAT-00002      HOSP-3  Northside Community Hospital
# HOSP-3-20240930-0002  PAT-00003      HOSP-3  Northside Community Hospital
# HOSP-2-20240227-0001  PAT-00004      HOSP-2      Riverside Medical Center
# HOSP-1-20240306-0002  PAT-00005      HOSP-1  Springfield General Hospital
# ...                         ...         ...                           ...
# HOSP-5-20241212-0989  PAT-04996      HOSP-5          Summit Health Center
# HOSP-4-20240630-0995  PAT-04997      HOSP-4    St. Mary’s Regional Health
# HOSP-2-20240213-1022  PAT-04998      HOSP-2      Riverside Medical Center
# HOSP-2-20240828-1023  PAT-04999      HOSP-2      Riverside Medical Center
# HOSP-1-20240825-0994  PAT-05000      HOSP-1  Springfield General Hospital
#
#                      Region           Visit Date Day of Week  Season  \
# Visit ID
# HOSP-1-20240210-0001  Urban  2024-02-10 20:20:56    Saturday  Winter
# HOSP-3-20241128-0001  Rural  2024-11-28 02:07:47    Thursday    Fall
# HOSP-3-20240930-0002  Rural  2024-09-30 04:02:28      Monday    Fall
# HOSP-2-20240227-0001  Urban  2024-02-27 00:31:13     Tuesday  Winter
# HOSP-1-20240306-0002  Urban  2024-03-06 16:52:26   Wednesday  Spring
# ...                     ...                  ...         ...     ...
# HOSP-5-20241212-0989  Urban  2024-12-12 04:29:36    Thursday  Winter
# HOSP-4-20240630-0995  Rural  2024-06-30 22:44:17      Sunday  Summer
# HOSP-2-20240213-1022  Urban  2024-02-13 21:06:17     Tuesday  Winter
# HOSP-2-20240828-1023  Urban  2024-08-28 03:11:51   Wednesday  Summer
# HOSP-1-20240825-0994  Urban  2024-08-25 23:05:40      Sunday  Summer
#
#                        Time of Day Urgency Level  Nurse-to-Patient Ratio  \
# Visit ID
# HOSP-1-20240210-0001  Late Morning        Medium                       4
# HOSP-3-20241128-0001       Evening        Medium                       4
# HOSP-3-20240930-0002       Evening           Low                       5
# HOSP-2-20240227-0001       Evening          High                       4
# HOSP-1-20240306-0002     Afternoon           Low                       4
# ...                            ...           ...                     ...
# HOSP-5-20241212-0989       Evening      Critical                       2
# HOSP-4-20240630-0995       Evening        Medium                       4
# HOSP-2-20240213-1022     Afternoon        Medium                       3
# HOSP-2-20240828-1023     Afternoon           Low                       5
# HOSP-1-20240825-0994       Evening        Medium                       4
#
#                       Specialist Availability  Facility Size (Beds)  \
# Visit ID
# HOSP-1-20240210-0001                        3                    92
# HOSP-3-20241128-0001                        0                    38
# HOSP-3-20240930-0002                        1                    38
# HOSP-2-20240227-0001                        5                    94
# HOSP-1-20240306-0002                        8                    74
# ...                                       ...                   ...
# HOSP-5-20241212-0989                        1                   142
# HOSP-4-20240630-0995                        0                    19
# HOSP-2-20240213-1022                        7                   163
# HOSP-2-20240828-1023                        4                   160
# HOSP-1-20240825-0994                        6                   176
#
#                       Time to Registration (min)  Time to Triage (min)  \
# Visit ID
# HOSP-1-20240210-0001                          17                    22
# HOSP-3-20241128-0001                           9                    30
# HOSP-3-20240930-0002                          38                    40
# HOSP-2-20240227-0001                           8                    16
# HOSP-1-20240306-0002                          26                    29
# ...                                          ...                   ...
# HOSP-5-20241212-0989                           6                    10
# HOSP-4-20240630-0995                           7                    23
# HOSP-2-20240213-1022                          14                    29
# HOSP-2-20240828-1023                          21                    35
# HOSP-1-20240825-0994                          20                    22
#
#                       Time to Medical Professional (min)  \
# Visit ID
# HOSP-1-20240210-0001                                  66
# HOSP-3-20241128-0001                                  30
# HOSP-3-20240930-0002                                 125
# HOSP-2-20240227-0001                                  64
# HOSP-1-20240306-0002                                  63
# ...                                                  ...
# HOSP-5-20241212-0989                                  19
# HOSP-4-20240630-0995                                  40
# HOSP-2-20240213-1022                                  87
# HOSP-2-20240828-1023                                  73
# HOSP-1-20240825-0994                                  77
#
#                       Total Wait Time (min)          Patient Outcome  \
# Visit ID
# HOSP-1-20240210-0001                    105               Discharged
# HOSP-3-20241128-0001                     69               Discharged
# HOSP-3-20240930-0002                    203               Discharged
# HOSP-2-20240227-0001                     88               Discharged
# HOSP-1-20240306-0002                    118               Discharged
# ...                                     ...                      ...
# HOSP-5-20241212-0989                     35               Discharged
# HOSP-4-20240630-0995                     70               Discharged
# HOSP-2-20240213-1022                    130               Discharged
# HOSP-2-20240828-1023                    129  Left Without Being Seen
# HOSP-1-20240825-0994                    119               Discharged
#
#                       Patient Satisfaction
# Visit ID
# HOSP-1-20240210-0001                     1
# HOSP-3-20241128-0001                     3
# HOSP-3-20240930-0002                     1
# HOSP-2-20240227-0001                     2
# HOSP-1-20240306-0002                     1
# ...                                    ...
# HOSP-5-20241212-0989                     3
# HOSP-4-20240630-0995                     3
# HOSP-2-20240213-1022                     1
# HOSP-2-20240828-1023                     1
# HOSP-1-20240825-0994                     1
#
# [5000 rows x 18 columns]>

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta

def generate_synthetic_data(n_samples=5000): # artificial realistic ED data
 
    np.random.seed(42)
    
    # realistic data distributions
    health_levels = ['RESUSCITATION', 'EMERGENT', 'URGENT', 'SEMI_URGENT', 'NON_URGENT']
    health_probabilities = [0.05, 0.15, 0.30, 0.35, 0.15] 
    
    complaints = [
        'Chest Pain', 'Fever', 'Broken Arm', 'Headache', 'Breathing Issues',
        'Stomach Pain', 'Back Pain', 'Dizziness', 'Nausea', 'Laceration',
        'Allergic Reaction', 'Anxiety', 'Fracture', 'Burns', 'Syncope'
    ]
    
    dispositions = ['Admitted', 'Discharged', 'AMA', 'Transferred', 'Observation']
    disposition_probs = [0.30, 0.60, 0.05, 0.03, 0.02]
    
    
    data = {
        'patient_id': range(1, n_samples + 1),
        'anonymousId': [f'PT-{i:05d}' for i in range(1, n_samples + 1)],
        
        # arrival times with realistic patterns (busier in morning/evening)
        'arrival_time': [
            datetime.now() - timedelta(
                hours=np.random.exponential(scale=12),
                minutes=np.random.randint(0, 60)
            ) for _ in range(n_samples)
        ],
        
    
        'triage': np.random.choice(health_levels, n_samples, p=health_probabilities),
        
       
        'complaint': np.random.choice(complaints, n_samples),
        
        
        'wait_time_minutes': np.random.exponential(scale=45, size=n_samples),
        
        
        'door_to_doctor_minutes': np.random.exponential(scale=60, size=n_samples),
        
        
        'length_of_stay_minutes': np.random.exponential(scale=120, size=n_samples),
        
       
        'left_without_seen': np.random.binomial(1, 0.06, n_samples),
        
        
        'discharge_disposition': np.random.choice(
            dispositions, n_samples, p=disposition_probs
        ),
        
        
        'patient_age': np.random.gamma(shape=2, scale=25, size=n_samples).astype(int) + 5,
        
        
        'gender': np.random.choice(['M', 'F'], n_samples, p=[0.48, 0.52]),
    }
    
    df = pd.DataFrame(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 71
#      65     df = pd.DataFrame(data)
#      67     df.head
# ---> 71 print(data.generate_synthetic_data(3000))
#
# NameError: name 'data' is not defined

# %%
nums = [2,7,11,15]
target = 9

for i in nums:
